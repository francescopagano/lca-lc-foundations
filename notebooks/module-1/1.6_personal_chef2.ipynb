# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:

    """Search the web for information"""

    return tavily_client.search(query)

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from psutil import users
from langgraph.checkpoint.memory import InMemorySaver  
from pprint import pprint

# %%
system_prompt = """

You are a chef/baker, create a recipe for the user's requested dish.

Please keep to the below structure.

Name: The name of the recipe

Origin: Where it is from

Process: the process of making the dish

Be concise in the answer.

You have access to tools that can help you search the web for information. 
Use them if you need to find information about the dish.
"""

chef = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt,
    checkpointer=InMemorySaver(),  
    tools=[web_search],
    
)

# %%
question = HumanMessage(
    content="Give me a recipe for a lemon cake"
)
config = {"configurable": {"thread_id": "1"}}

# %%
response = chef.invoke(
    {"messages": [question]},
    config
)

pprint(response)
# Out:
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://eu.api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://eu.api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# {'messages': [HumanMessage(content='Give me a recipe for a lemon cake', additional_kwargs={}, response_metadata={}, id='b32a1811-1c5a-42ed-a1c2-98b723dce76c'),
#               AIMessage(content='Name: Classic Lemon Cake with Lemon Glaze\n\nOrigin: A classic Western dessert; popular in Europe and North America.\n\nProcess:\n- Ingredients (serves 8):\n  - 1 3/4 cups (220 g) all-purpose flour\n  - 1 1/2 tsp baking powder\n  - 1/4 tsp salt\n  - 1/2 cup (115 g) unsalted butter, softened\n  - 1 cup (200 g) granulated sugar\n  - 2 large eggs\n  - 1/2 cup (120 ml) milk\n  - 2 Tbsp lemon zest\n  - 1/4 cup (60 ml) lemon juice\n  - 1 tsp vanilla extract (optional)\n- For glaze:\n  - 1 cup (120 g) powdered sugar\n  - 2–3 Tbsp lemon juice\n- Optional lemon syrup (to moisten):\n  - 2 Tbsp lemon juice\n  - 1 Tbsp granulated sugar\n\n- Steps:\n  1) Preheat to 350°F (175°C). Grease and flour a 9-inch round pan.\n  2) Whisk dry: flour, baking powder, salt.\n  3) Cream butter and sugar until light. Beat in eggs one by one. Mix in lemon zest, lemon juice, and vanilla.\n  4) Add dry ingredients in 2 additions, alternating with milk; mix until just combined.\n  5) Bake 25–30 minutes until a toothpick comes out clean. Cool 10 minutes in the pan, then transfer to a rack.\n  6) (Optional) Brush cake with lemon syrup while warm.\n  7) Whisk glaze ingredients until smooth; drizzle over cooled cake and garnish with extra zest.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 2044, 'prompt_tokens': 216, 'total_tokens': 2260, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1664, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DwkxcQiWYMnxxO5Ag6RN2TGk1yTW1', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f1ce0-a544-7352-96cf-113b9f1c68fc-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 216, 'output_tokens': 2044, 'total_tokens': 2260, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1664}})]}

# %%
question = HumanMessage(content = "Can you tell me the most important ingredient for the recipe?")

response = chef.invoke(
    {"messages": [question]},
    config
)

pprint(response)
# Out:
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://eu.api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://eu.api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# {'messages': [HumanMessage(content='Give me a recipe for a lemon cake', additional_kwargs={}, response_metadata={}, id='b32a1811-1c5a-42ed-a1c2-98b723dce76c'),
#               AIMessage(content='Name: Classic Lemon Cake with Lemon Glaze\n\nOrigin: A classic Western dessert; popular in Europe and North America.\n\nProcess:\n- Ingredients (serves 8):\n  - 1 3/4 cups (220 g) all-purpose flour\n  - 1 1/2 tsp baking powder\n  - 1/4 tsp salt\n  - 1/2 cup (115 g) unsalted butter, softened\n  - 1 cup (200 g) granulated sugar\n  - 2 large eggs\n  - 1/2 cup (120 ml) milk\n  - 2 Tbsp lemon zest\n  - 1/4 cup (60 ml) lemon juice\n  - 1 tsp vanilla extract (optional)\n- For glaze:\n  - 1 cup (120 g) powdered sugar\n  - 2–3 Tbsp lemon juice\n- Optional lemon syrup (to moisten):\n  - 2 Tbsp lemon juice\n  - 1 Tbsp granulated sugar\n\n- Steps:\n  1) Preheat to 350°F (175°C). Grease and flour a 9-inch round pan.\n  2) Whisk dry: flour, baking powder, salt.\n  3) Cream butter and sugar until light. Beat in eggs one by one. Mix in lemon zest, lemon juice, and vanilla.\n  4) Add dry ingredients in 2 additions, alternating with milk; mix until just combined.\n  5) Bake 25–30 minutes until a toothpick comes out clean. Cool 10 minutes in the pan, then transfer to a rack.\n  6) (Optional) Brush cake with lemon syrup while warm.\n  7) Whisk glaze ingredients until smooth; drizzle over cooled cake and garnish with extra zest.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 2044, 'prompt_tokens': 216, 'total_tokens': 2260, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1664, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DwkxcQiWYMnxxO5Ag6RN2TGk1yTW1', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f1ce0-a544-7352-96cf-113b9f1c68fc-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 216, 'output_tokens': 2044, 'total_tokens': 2260, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1664}}),
#               HumanMessage(content='Can you tell me the most important ingredient for the recipe?', additional_kwargs={}, response_metadata={}, id='2030cdc2-b46a-477b-85ac-7ea7369c63f5'),
#               AIMessage(content='Name: Classic Lemon Cake with Lemon Glaze\n\nOrigin: A classic Western dessert; popular in Europe and North America.\n\nProcess:\n- Most important ingredient: lemon zest. It contains the essential oils that give the cake its authentic lemon aroma and flavor; lemon juice adds brightness but cannot replace the zest’s aromatic punch. If you only have juice, you can still use it, but grate the zest whenever possible for best flavor.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1118, 'prompt_tokens': 609, 'total_tokens': 1727, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1024, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Dwkxs2qwbkXbdANxy7mU2RIiHuiTm', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f1ce0-e20d-7190-9251-c8aa3ddb56ad-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 609, 'output_tokens': 1118, 'total_tokens': 1727, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1024}})]}
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://eu.api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://eu.api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
