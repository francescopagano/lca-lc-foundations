# %% [markdown]
# ## Basic prompting

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

agent = create_agent(model="gpt-5-nano")

question = HumanMessage(content="What's the capital of the moon?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# There isn’t one. The Moon isn’t a country and has no government or capital. If a future lunar settlement were established, its capital would be determined by the governing authority that runs it (and there’s no such authority today). If you’re thinking of a specific sci‑fi universe, tell me which one and I can name its version.

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# In this sci‑fi setting, the Moon’s capital is Lunaris Prime.
#
# A quick tour of Lunaris Prime:
# - Location: Built inside and along the rim of a colossal crater on the near side (think a modern, glassy fortress perched above a pale lunar sea). The heart sits near the crater floor, with transit rings weaving in and out of the rim for rapid Earth-Moon travel.
# - Government: The Lunar Republic’s seat of power. The Lunar Council governs from the Glass Hall, led by a Chancellor elected for a fixed term. The capital houses judiciary, ministries, and the archive of lunar law.
# - Architecture: A fusion of sculpted regolith, transparent domes, and 3D-printed habitats. Hexagonal modules cluster into arcologies, connected by gravity-tubes and solar-albedo gardens that glow softly at night.
# - Economy: A hub for helium-3 mining, water-ice extraction, biotech labs, and lunar manufacturing. Spaceports are busy with Earth-Moon shuttle traffic; a vibrant trade in lunar minerals and synthetic foods.
# - Culture: Multinational and multilingual—the Moon’s population is a blend of Earth-born settlers and lunar-born pioneers. Festivals celebrate Earthrise, the Day of Dust and Light, and moonlit performances in zero-g theaters.
# - Landmarks: The Helix Tower (a spiraling megastructure housing research and housing), The Beacon of Terra (a data beacon that links lunar archives to Earth), and the Archive of Echoes (a living library carved into a crater wall).
# - Daily life: Gravity-adjusted parks, markets under crystal domes, and elevated promenades that look out over a pale, silent sea of regolith. Energy and air are carefully recycled in compact, elegant cycles.
# - Transport: Lunar elevators reach the rim, magnetic rails crisscross the crater floor, and autonomous shuttles shuttle between districts.
#
# If you’d like, I can tailor Lunaris Prime to a different mood (gritty frontier city, utopian beacon, or militarized stronghold), or sketch a map and a short scene set there. Would you prefer a different name or vibe for the capital?

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Lunapolis

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Name: Selene Prime
# Location: Shackleton Crater, lunar south pole
# Vibe: Neon-lit lunar frontier
# Economy: Helium-3 mining; water-ice processing; lunar manufacturing and 3D printing; orbital logistics and research facilities

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    model='gpt-5-nano',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]
# Out:
# CapitalInfo(name='Selene Prime', location='Shackleton Crater rim, lunar south pole', vibe='A solar-powered capital rising from polar twilight, with glass-and-regolith architecture, expansive skylights, and a ceremonial-pioneer atmosphere where governance, science, and culture converge at the edge of permanent daylight.', economy='Helium-3 and water-ice extraction, in-situ manufacturing, lunar research institutes, spaceport logistics, and polar-tourism.')

# %%
response["structured_response"].name
# Out:
# 'Selene Prime'

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
# Out:
# Selene Prime is a city located at Shackleton Crater rim, lunar south pole
